# %%
# ASK USER FOR SCORES
MTH_101 = float(input("Enter your MTH 101 score: "))
CSC_101 = float(input("Enter your CSC 101 score: "))
CHM_101 = float(input("Enter your CHM 101 score: "))
PHY_101 = float(input("Enter your PHY 101 score: "))
PHY_103 = float(input("Enter your PHY 103 score: "))
STA_105 = float(input("Enter your STA 105 score: "))
GST_103 = float(input("Enter your GST 103 score: "))
GST_105 = float(input("Enter your GST 105 score: "))

# CALCULATE TOTAL
TOTAL = (MTH_101 + CSC_101 + CHM_101 + PHY_101 + PHY_103 + STA_105 + GST_103 + GST_105)

# CALCULATE AVERAGE
AVERAGE = TOTAL / 8

# CALCULATE PERCENTAGE
PERCENTAGE = (TOTAL / 800) * 100

# ASSIGN GRADES TO ALL COURSES
if MTH_101 > 69:
    MTH_101_GRADE = "A"
elif MTH_101 > 60:
    MTH_101_GRADE = "B"
elif MTH_101 > 50:
    MTH_101_GRADE = "C"
elif MTH_101 > 40:
    MTH_101_GRADE = "D"
else:
    MTH_101_GRADE = "F"

if CSC_101 > 69:
    CSC_101_GRADE = "A"
elif CSC_101 > 60:
    CSC_101_GRADE = "B"
elif CSC_101 > 50:
    CSC_101_GRADE = "C"
elif CSC_101 > 40:
    CSC_101_GRADE = "D"
else:
    CSC_101_GRADE = "F"

if CHM_101 > 69:
    CHM_101_GRADE = "A"
elif CHM_101 > 60:
    CHM_101_GRADE = "B"
elif CHM_101 > 50:
    CHM_101_GRADE = "C"
elif CHM_101 > 40:
    CHM_101_GRADE = "D"
else:
    CHM_101_GRADE = "F"

if PHY_101 > 69:
    PHY_101_GRADE = "A"
elif PHY_101 > 60:
    PHY_101_GRADE = "B"
elif PHY_101 > 50:
    PHY_101_GRADE = "C"
elif PHY_101 > 40:
    PHY_101_GRADE = "D"
else:
    PHY_101_GRADE = "F"

if PHY_103 > 69:
    PHY_103_GRADE = "A"
elif PHY_103 > 60:
    PHY_103_GRADE = "B"
elif PHY_103 > 50:
    PHY_103_GRADE = "C"
elif PHY_103 > 40:
    PHY_103_GRADE = "D"
else:
    PHY_103_GRADE = "F"

if STA_105 > 69:
    STA_105_GRADE = "A"
elif STA_105 > 60:
    STA_105_GRADE = "B"
elif STA_105 > 50:
    STA_105_GRADE = "C"
elif STA_105 > 40:
    STA_105_GRADE = "D"
else:
    STA_105_GRADE = "F"
    
if STA_105 > 69:
    STA_105_GRADE = "A"
elif STA_105 > 60 and STA_105 < 68:
    STA_105_GRADE = "B"
elif STA_105 > 50 and STA_105 < 58:
    STA_105_GRADE = "C"
elif STA_105 > 40 and STA_105 < 48:
    STA_105_GRADE = "D"
else:
    STA_105_GRADE = "F"

if GST_103 > 69:
    GST_103_GRADE = "A"
elif GST_103 > 60 and GST_103 < 68:
    GST_103_GRADE = "B"
elif GST_103 > 50 and GST_103 < 58:
    GST_103_GRADE = "C"
elif GST_103 > 40 and GST_103 < 48:
    GST_103_GRADE = "D"
else:
    GST_103_GRADE = "F"

if GST_105 > 69:
    GST_105_GRADE = "A"
elif GST_105 > 60 and GST_105 < 68:
    GST_105_GRADE = "B"
elif GST_105 > 50 and GST_105 < 58:
    GST_105_GRADE = "C"
elif GST_105 > 40 and GST_105 < 48:
    GST_105_GRADE = "D"
else:
    GST_105_GRADE = "F"

#ASSIGNING GRADE POINTS
if MTH_101_GRADE == "A":
    MTH_101_GP = 5
elif MTH_101_GRADE == "B":
    MTH_101_GP = 4
elif MTH_101_GRADE == "C":
    MTH_101_GP = 3
elif MTH_101_GRADE == "D":
    MTH_101_GP = 2
else:
    MTH_101_GP = 1
    
if CSC_101_GRADE == "A":
    CSC_101_GP = 5
elif CSC_101_GRADE == "B":
    CSC_101_GP = 4
elif CSC_101_GRADE == "C":
    CSC_101_GP = 3
elif CSC_101_GRADE == "D":
    CSC_101_GP = 2
else:
    CSC_101_GP = 1
    
if CHM_101_GRADE == "A":
    CHM_101_GP = 5
elif CHM_101_GRADE == "B":
    CHM_101_GP = 4
elif CHM_101_GRADE == "C":
    CHM_101_GP = 3
elif CHM_101_GRADE == "D":
    CHM_101_GP = 2
else:
    CHM_101_GP = 1
    
if PHY_101_GRADE == "A":
    PHY_101_GP = 5
elif PHY_101_GRADE == "B":
    PHY_101_GP = 4
elif PHY_101_GRADE == "C":
    PHY_101_GP = 3
elif PHY_101_GRADE == "D":
    PHY_101_GP = 2
else:
    PHY_101_GP = 1
    
if PHY_103_GRADE == "A":
    PHY_103_GP = 5
elif PHY_103_GRADE == "B":
    PHY_103_GP = 4
elif PHY_103_GRADE == "C":
    PHY_103_GP = 3
elif PHY_103_GRADE == "D":
    PHY_103_GP = 2
else:
    PHY_103_GP = 1
    
if STA_105_GRADE == "A":
    STA_105_GP = 5
elif STA_105_GRADE == "B":
    STA_105_GP = 4
elif STA_105_GRADE == "C":
    STA_105_GP = 3
elif STA_105_GRADE == "D":
    STA_105_GP = 2
else:
    STA_105_GP = 1   
    
if GST_103_GRADE == "A":
    GST_103_GP = 5
elif GST_103_GRADE == "B":
    GST_103_GP = 4
elif GST_103_GRADE == "C":
    GST_103_GP = 3
elif GST_103_GRADE == "D":
    GST_103_GP = 2
else:
    GST_103_GP = 1
    
if GST_105_GRADE == "A":
    GST_105_GP = 5
elif GST_105_GRADE == "B":
    GST_105_GP = 4
elif GST_105_GRADE == "C":
    GST_105_GP = 3
elif GST_105_GRADE == "D":
    GST_105_GP = 2
else:
    GST_105_GP = 1      
    
#STATE THE UNIT POINTS OF THE COURSES
MTH_101_UP = 3
CSC_101_UP = 1
CHM_101_UP = 3
PHY_101_UP = 3
PHY_103_UP = 1
STA_105_UP = 3
GST_103_UP = 2
GST_105_UP = 2 

# CALCULATE GPA
GPA = ((MTH_101_GP * MTH_101_UP) + (CSC_101_GP * CSC_101_UP) + (CHM_101_GP * CHM_101_UP) + (PHY_101_GP * PHY_101_UP) + (PHY_103_GP * PHY_103_UP) + (STA_105_GP * STA_105_UP) + (GST_103_GP * GST_103_UP) + (GST_105_GP * GST_105_UP))/ (MTH_101_UP + CSC_101_UP + CHM_101_UP + PHY_101_UP + PHY_103_UP + STA_105_UP + GST_103_UP + GST_105_UP) 

# OUTPUT
print("Your Total score is:", TOTAL, "\nYour Average is:", AVERAGE, "\nYour percentage is:", PERCENTAGE, "\nYour GPA is:", GPA)
# Out:
# Enter your MTH 101 score: 100
# Enter your CSC 101 score: 90
# Enter your CHM 101 score: 80
# Enter your PHY 101 score: 70
# Enter your PHY 103 score: 60
# Enter your STA 105 score: 65
# Enter your GST 103 score: 70
# Enter your GST 105 score: 75
# Your Total score is: 610.0
# Your Average is: 76.25
# Your percentage is: 76.25
# Your GPA is: 4.722222222222222
